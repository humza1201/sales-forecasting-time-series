# %%
import pandas as pd

# %%
data = pd.read_csv('features.csv')

# %%
df_features = pd.DataFrame(data)

# %%
df_features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
stores = pd.read_csv('stores.csv')
df_stores = pd.DataFrame(stores)

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
train_data = pd.read_csv('train.csv')

# %%
df_train = pd.DataFrame(train_data)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
df_train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df_train['Date'].min()
# Out:
# '2010-02-05'

# %%
df_train['Date'].max()
# Out:
# '2012-10-26'

# %%
df_train['Store'].nunique()
# Out:
# 45

# %%
df_train['Dept'].nunique()
# Out:
# 81

# %%
df_train.groupby('Date')['Weekly_Sales'].sum().plot(figsize = (12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])

# %%
df_features['Date'] = pd.to_datetime(df_features['Date'])

# %%
test_data = pd.read_csv('test.csv')
df_test = pd.DataFrame(test_data)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Store      115064 non-null  int64
#  1   Dept       115064 non-null  int64
#  2   Date       115064 non-null  object
#  3   IsHoliday  115064 non-null  bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB

# %%
df_test['Date'] = pd.to_datetime(df_test['Date'])

# %%
pd.date_range(start='2010-02-05' , end ='2012-10-26' )
# Out:
# DatetimeIndex(['2010-02-05', '2010-02-06', '2010-02-07', '2010-02-08',
#                '2010-02-09', '2010-02-10', '2010-02-11', '2010-02-12',
#                '2010-02-13', '2010-02-14',
#                ...
#                '2012-10-17', '2012-10-18', '2012-10-19', '2012-10-20',
#                '2012-10-21', '2012-10-22', '2012-10-23', '2012-10-24',
#                '2012-10-25', '2012-10-26'],
#               dtype='datetime64[ns]', length=995, freq='D')

# %%
df = df_train.merge(df_features , on= ['Store', 'Date', 'IsHoliday'], how='left')

# %%
df = df.merge(df_stores, on=['Store'], how='left')

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     1 2010-02-12      46039.49       True        38.51
# 2           1     1 2010-02-19      41595.55      False        39.93
# 3           1     1 2010-02-26      19403.54      False        46.63
# 4           1     1 2010-03-05      21827.90      False        46.50
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    98 2012-09-28        508.37      False        64.88
# 421566     45    98 2012-10-05        628.10      False        64.89
# 421567     45    98 2012-10-12       1061.02      False        54.47
# 421568     45    98 2012-10-19        760.01      False        56.47
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.548        NaN        NaN        NaN        NaN        NaN
# 2            2.514        NaN        NaN        NaN        NaN        NaN
# 3            2.561        NaN        NaN        NaN        NaN        NaN
# 4            2.625        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.997    4556.61      20.64       1.50    1601.01    3288.25
# 421566       3.985    5046.74        NaN      18.82    2253.43    2340.01
# 421567       4.000    1956.28        NaN       7.89     599.32    3990.54
# 421568       3.969    2004.02        NaN       3.18     437.73    1537.49
# 421569       3.882    4018.91      58.08     100.00     211.94     858.33
#
#                CPI  Unemployment Type    Size
# 0       211.096358         8.106    A  151315
# 1       211.242170         8.106    A  151315
# 2       211.289143         8.106    A  151315
# 3       211.319643         8.106    A  151315
# 4       211.350143         8.106    A  151315
# ...            ...           ...  ...     ...
# 421565  192.013558         8.684    B  118221
# 421566  192.170412         8.667    B  118221
# 421567  192.327265         8.667    B  118221
# 421568  192.330854         8.667    B  118221
# 421569  192.308899         8.667    B  118221
#
# [421570 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     150681 non-null  float64
#  8   MarkDown2     111248 non-null  float64
#  9   MarkDown3     137091 non-null  float64
#  10  MarkDown4     134967 non-null  float64
#  11  MarkDown5     151432 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 48.6+ MB

# %%
df.shape
# Out:
# (421570, 16)

# %%
df.isna().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# Type                 0
# Size                 0
# dtype: int64

# %%
sample = df[(df['Store']==1) & (df['Dept']==1)]
sample = sample.sort_values('Date')

# %%
expected_dates = pd.date_range(
    start=sample['Date'].min(),
    end=sample['Date'].max(),
    freq='W-FRI'
)

# %%
missing_dates = expected_dates.difference(sample['Date'])

# %%
missing_dates
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='W-FRI')

# %%
len(missing_dates)
# Out:
# 0

# %%
weekly_total = df.groupby('Date')['Weekly_Sales'].sum().sort_index()

# %%
y = weekly_total

naive_forecast = y.shift(1)

y_true = y[1:]
y_pred = naive_forecast[1:]

# %%
y_true
# Out:
# Date
# 2010-02-12    48336677.63
# 2010-02-19    48276993.78
# 2010-02-26    43968571.13
# 2010-03-05    46871470.30
# 2010-03-12    45925396.51
#                  ...
# 2012-09-28    43734899.40
# 2012-10-05    47566639.31
# 2012-10-12    46128514.25
# 2012-10-19    45122410.57
# 2012-10-26    45544116.29
# Name: Weekly_Sales, Length: 142, dtype: float64

# %%
y_pred
# Out:
# Date
# 2010-02-12    49750740.50
# 2010-02-19    48336677.63
# 2010-02-26    48276993.78
# 2010-03-05    43968571.13
# 2010-03-12    46871470.30
#                  ...
# 2012-09-28    44354547.11
# 2012-10-05    43734899.40
# 2012-10-12    47566639.31
# 2012-10-19    46128514.25
# 2012-10-26    45122410.57
# Name: Weekly_Sales, Length: 142, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error

mae_naive = mean_absolute_error(y_true, y_pred)
mae_naive
# Out:
# 3144516.728239436

# %%
df['Weekly_Sales'].rolling(window=4).mean()
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3         32990.7700
# 4         32216.6200
#              ...
# 421565      483.5175
# 421566      552.4325
# 421567      666.1975
# 421568      739.3750
# 421569      881.4825
# Name: Weekly_Sales, Length: 421570, dtype: float64

# %%
df['Weekly_Sales'].rolling(window=12).mean()
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#              ...
# 421565    553.146667
# 421566    547.554167
# 421567    565.530833
# 421568    574.062500
# 421569    620.757500
# Name: Weekly_Sales, Length: 421570, dtype: float64

# %%
y_pred_ma4 = weekly_total.rolling(window=4).mean().shift(1)
y_pred_ma12 = weekly_total.rolling(window=12).mean().shift(1)

# Align properly
y_true_ma4 = weekly_total[y_pred_ma4.notna()]
y_pred_ma4 = y_pred_ma4.dropna()

y_true_ma12 = weekly_total[y_pred_ma12.notna()]
y_pred_ma12 = y_pred_ma12.dropna()

# %%
mae_ma4 = mean_absolute_error(y_true_ma4, y_pred_ma4)
mae_ma12 = mean_absolute_error(y_true_ma12, y_pred_ma12)

# %%
mae_ma12
# Out:
# 3413474.5566284982

# %%
mae_ma4
# Out:
# 3217972.910791367

# %%
y_pred_seasonal = weekly_total.shift(52)

y_true_seasonal = weekly_total[y_pred_seasonal.notna()]
y_pred_seasonal = y_pred_seasonal.dropna()

# %%
mae_seasonal = mean_absolute_error(y_true_seasonal, y_pred_seasonal)
mae_seasonal
# Out:
# 1432946.5896703294

# %%
split_date = weekly_total.index.max() - pd.DateOffset(months = 6)

# %%
train_ts = weekly_total[weekly_total.index <= split_date]
test_ts = weekly_total[weekly_total.index > split_date]

# %%
y_pred_seasonal_test = weekly_total.shift(52)
y_true_seasonal_test = weekly_total[y_pred_seasonal_test.notna()]
y_pred_seasonal_test = y_pred_seasonal_test.dropna()

# %%
mae_re_evaluate_on_test = mean_absolute_error(y_true_seasonal_test, y_pred_seasonal_test)

# %%
mae_re_evaluate_on_test
# Out:
# 1432946.5896703294

# %%
weekly_total
# Out:
# Date
# 2010-02-05    49750740.50
# 2010-02-12    48336677.63
# 2010-02-19    48276993.78
# 2010-02-26    43968571.13
# 2010-03-05    46871470.30
#                  ...
# 2012-09-28    43734899.40
# 2012-10-05    47566639.31
# 2012-10-12    46128514.25
# 2012-10-19    45122410.57
# 2012-10-26    45544116.29
# Name: Weekly_Sales, Length: 143, dtype: float64

# %%
timeseries_df = pd.DataFrame({'y': weekly_total})

# %%
timeseries_df
# Out:
#                       y
# Date
# 2010-02-05  49750740.50
# 2010-02-12  48336677.63
# 2010-02-19  48276993.78
# 2010-02-26  43968571.13
# 2010-03-05  46871470.30
# ...                 ...
# 2012-09-28  43734899.40
# 2012-10-05  47566639.31
# 2012-10-12  46128514.25
# 2012-10-19  45122410.57
# 2012-10-26  45544116.29
#
# [143 rows x 1 columns]

# %%
for lag in [1, 2, 4, 52]:
    timeseries_df[f'lag_{lag}'] = timeseries_df['y'].shift(lag)

# %%
timeseries_df['rolling_mean_4'] = timeseries_df['y'].rolling(window=4).mean().shift(1)
timeseries_df['rolling_mean_12'] = timeseries_df['y'].rolling(window=12).mean().shift(1)

# %%
timeseries_df
# Out:
#                       y        lag_1        lag_2        lag_4       lag_52  \
# Date
# 2010-02-05  49750740.50          NaN          NaN          NaN          NaN
# 2010-02-12  48336677.63  49750740.50          NaN          NaN          NaN
# 2010-02-19  48276993.78  48336677.63  49750740.50          NaN          NaN
# 2010-02-26  43968571.13  48276993.78  48336677.63          NaN          NaN
# 2010-03-05  46871470.30  43968571.13  48276993.78  49750740.50          NaN
# ...                 ...          ...          ...          ...          ...
# 2012-09-28  43734899.40  44354547.11  44226038.65  47159639.43  42195830.81
# 2012-10-05  47566639.31  43734899.40  44354547.11  48330059.31  47211688.36
# 2012-10-12  46128514.25  47566639.31  43734899.40  44226038.65  44374820.30
# 2012-10-19  45122410.57  46128514.25  47566639.31  44354547.11  45818953.44
# 2012-10-26  45544116.29  45122410.57  46128514.25  43734899.40  45855821.05
#
#             rolling_mean_4  rolling_mean_12
# Date
# 2010-02-05             NaN              NaN
# 2010-02-12             NaN              NaN
# 2010-02-19             NaN              NaN
# 2010-02-26             NaN              NaN
# 2010-03-05    4.758325e+07              NaN
# ...                    ...              ...
# 2012-09-28    4.601757e+07     4.677257e+07
# 2012-10-05    4.516139e+07     4.614606e+07
# 2012-10-12    4.497053e+07     4.626830e+07
# 2012-10-19    4.544615e+07     4.627405e+07
# 2012-10-26    4.563812e+07     4.635949e+07
#
# [143 rows x 7 columns]

# %%
timeseries_df = timeseries_df.dropna()

# %%
timeseries_df
# Out:
#                       y        lag_1        lag_2        lag_4       lag_52  \
# Date
# 2011-02-04  46153111.12  39599852.99  40654648.03  42775787.77  49750740.50
# 2011-02-11  47336192.79  46153111.12  39599852.99  40673678.04  48336677.63
# 2011-02-18  48716164.12  47336192.79  46153111.12  40654648.03  48276993.78
# 2011-02-25  44125859.84  48716164.12  47336192.79  39599852.99  43968571.13
# 2011-03-04  46980603.74  44125859.84  48716164.12  46153111.12  46871470.30
# ...                 ...          ...          ...          ...          ...
# 2012-09-28  43734899.40  44354547.11  44226038.65  47159639.43  42195830.81
# 2012-10-05  47566639.31  43734899.40  44354547.11  48330059.31  47211688.36
# 2012-10-12  46128514.25  47566639.31  43734899.40  44226038.65  44374820.30
# 2012-10-19  45122410.57  46128514.25  47566639.31  44354547.11  45818953.44
# 2012-10-26  45544116.29  45122410.57  46128514.25  43734899.40  45855821.05
#
#             rolling_mean_4  rolling_mean_12
# Date
# 2011-02-04    4.092599e+07     5.079466e+07
# 2011-02-11    4.177032e+07     5.079702e+07
# 2011-02-18    4.343595e+07     5.098123e+07
# 2011-02-25    4.545133e+07     4.955583e+07
# 2011-03-04    4.658283e+07     4.907390e+07
# ...                    ...              ...
# 2012-09-28    4.601757e+07     4.677257e+07
# 2012-10-05    4.516139e+07     4.614606e+07
# 2012-10-12    4.497053e+07     4.626830e+07
# 2012-10-19    4.544615e+07     4.627405e+07
# 2012-10-26    4.563812e+07     4.635949e+07
#
# [91 rows x 7 columns]

# %%
split_dates = timeseries_df.index.max() - pd.DateOffset(months = 6)

# %%
train_df = timeseries_df[timeseries_df.index <= split_date]
test_df = timeseries_df[timeseries_df.index > split_date]

# %%
train_df
# Out:
#                       y        lag_1        lag_2        lag_4       lag_52  \
# Date
# 2011-02-04  46153111.12  39599852.99  40654648.03  42775787.77  49750740.50
# 2011-02-11  47336192.79  46153111.12  39599852.99  40673678.04  48336677.63
# 2011-02-18  48716164.12  47336192.79  46153111.12  40654648.03  48276993.78
# 2011-02-25  44125859.84  48716164.12  47336192.79  39599852.99  43968571.13
# 2011-03-04  46980603.74  44125859.84  48716164.12  46153111.12  46871470.30
# ...                 ...          ...          ...          ...          ...
# 2012-03-23  44993794.45  46901504.94  47480454.11  45771506.57  42876199.18
# 2012-03-30  45272862.02  44993794.45  46901504.94  46861034.97  43458991.19
# 2012-04-06  53502315.87  45272862.02  44993794.45  47480454.11  45887466.80
# 2012-04-13  46629261.41  53502315.87  45272862.02  46901504.94  44973328.14
# 2012-04-20  45072529.78  46629261.41  53502315.87  44993794.45  48676692.06
#
#             rolling_mean_4  rolling_mean_12
# Date
# 2011-02-04    4.092599e+07     5.079466e+07
# 2011-02-11    4.177032e+07     5.079702e+07
# 2011-02-18    4.343595e+07     5.098123e+07
# 2011-02-25    4.545133e+07     4.955583e+07
# 2011-03-04    4.658283e+07     4.907390e+07
# ...                    ...              ...
# 2012-03-23    4.675363e+07     4.568696e+07
# 2012-03-30    4.655920e+07     4.559957e+07
# 2012-04-06    4.616215e+07     4.562602e+07
# 2012-04-13    4.766762e+07     4.658263e+07
# 2012-04-20    4.759956e+07     4.696165e+07
#
# [64 rows x 7 columns]

# %%
x_train = train_df.drop(columns='y')
y_train = train_df['y']

x_test = test_df.drop(columns='y')
y_test = test_df['y']

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = reg.predict(x_test)

# %%
predictions
# Out:
# array([44222602.66950763, 46802766.25953142, 45923075.38085128,
#        44845011.72977116, 45834599.59404569, 48800022.93028548,
#        47974590.66116083, 47953305.21303397, 46607665.82056312,
#        47885722.40803538, 47961832.27907146, 46512774.9108915 ,
#        45929997.37397473, 44464033.55269434, 47821391.10554788,
#        46652343.29331566, 47298819.62053829, 47677747.70056017,
#        46028815.18031471, 47123215.9777128 , 44809066.17898805,
#        43529969.01646391, 42980051.77557913, 47001871.6489491 ,
#        45050760.01583543, 46198885.45755869, 46071982.27968879])

# %%
from sklearn.metrics import mean_absolute_error

# %%
MAE = mean_absolute_error(y_test, predictions)

# %%
MAE
# Out:
# 895930.2227053789

# %%
mae_seasonal
# Out:
# 1432946.5896703294

# %%
coef_df = pd.DataFrame({
    'feature': x_train.columns,
    'coefficient': reg.coef_
}).sort_values(by='coefficient', key=abs, ascending=False)

coef_df
# Out:
#            feature  coefficient
# 3           lag_52     0.816659
# 0            lag_1     0.106135
# 5  rolling_mean_12     0.053319
# 1            lag_2     0.033101
# 4   rolling_mean_4    -0.014033
# 2            lag_4     0.007242

# %%
residuals = y_test - predictions

# %%
residuals
# Out:
# Date
# 2012-04-27   -5.058038e+05
# 2012-05-04    3.214317e+05
# 2012-05-11    1.002804e+06
# 2012-05-18    1.978927e+06
# 2012-05-25    2.057864e+06
# 2012-06-01   -5.183732e+05
# 2012-06-08    1.676581e+06
# 2012-06-15    4.588055e+05
# 2012-06-22    1.060619e+06
# 2012-06-29   -1.288610e+06
# 2012-07-06    3.291190e+06
# 2012-07-13   -4.130428e+05
# 2012-07-20    1.295461e+05
# 2012-07-27   -3.668786e+05
# 2012-08-03   -3.354915e+05
# 2012-08-10    7.511077e+05
# 2012-08-17    5.563243e+04
# 2012-08-24   -2.304241e+05
# 2012-08-31    1.130824e+06
# 2012-09-07    1.206843e+06
# 2012-09-14   -5.830275e+05
# 2012-09-21    8.245781e+05
# 2012-09-28    7.548476e+05
# 2012-10-05    5.647677e+05
# 2012-10-12    1.077754e+06
# 2012-10-19   -1.076475e+06
# 2012-10-26   -5.278660e+05
# Name: y, dtype: float64

# %%
res_df = pd.DataFrame({
    'date': y_test.index,
    'actual': y_test.values,
    'predicted': predictions,
    'residual': residuals
}).set_index('date')

# %%
res_df
# Out:
#                  actual     predicted      residual
# date
# 2012-04-27  43716798.89  4.422260e+07 -5.058038e+05
# 2012-05-04  47124197.93  4.680277e+07  3.214317e+05
# 2012-05-11  46925878.99  4.592308e+07  1.002804e+06
# 2012-05-18  46823939.22  4.484501e+07  1.978927e+06
# 2012-05-25  47892463.31  4.583460e+07  2.057864e+06
# 2012-06-01  48281649.72  4.880002e+07 -5.183732e+05
# 2012-06-08  49651171.78  4.797459e+07  1.676581e+06
# 2012-06-15  48412110.70  4.795331e+07  4.588055e+05
# 2012-06-22  47668284.97  4.660767e+07  1.060619e+06
# 2012-06-29  46597112.12  4.788572e+07 -1.288610e+06
# 2012-07-06  51253021.88  4.796183e+07  3.291190e+06
# 2012-07-13  46099732.10  4.651277e+07 -4.130428e+05
# 2012-07-20  46059543.45  4.593000e+07  1.295461e+05
# 2012-07-27  44097154.97  4.446403e+07 -3.668786e+05
# 2012-08-03  47485899.56  4.782139e+07 -3.354915e+05
# 2012-08-10  47403451.04  4.665234e+07  7.511077e+05
# 2012-08-17  47354452.05  4.729882e+07  5.563243e+04
# 2012-08-24  47447323.60  4.767775e+07 -2.304241e+05
# 2012-08-31  47159639.43  4.602882e+07  1.130824e+06
# 2012-09-07  48330059.31  4.712322e+07  1.206843e+06
# 2012-09-14  44226038.65  4.480907e+07 -5.830275e+05
# 2012-09-21  44354547.11  4.352997e+07  8.245781e+05
# 2012-09-28  43734899.40  4.298005e+07  7.548476e+05
# 2012-10-05  47566639.31  4.700187e+07  5.647677e+05
# 2012-10-12  46128514.25  4.505076e+07  1.077754e+06
# 2012-10-19  45122410.57  4.619889e+07 -1.076475e+06
# 2012-10-26  45544116.29  4.607198e+07 -5.278660e+05

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(res_df.index, res_df['residual'])
plt.xlabel('date')
plt.ylabel('residuals')
plt.axhline(0, linestyle='--')
plt.title('residuals over time')
plt.grid(True)
plt.show()
